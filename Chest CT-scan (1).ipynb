# %% [markdown]
# ### Data story
# contain 3 chest cancer types which are Adenocarcinoma,Large cell carcinoma, Squamous cell carcinoma , and 1 folder for the normal cell
# Data folder is the main folder that contain all the step folders
# inside Data folder are test , train , valid
#
# test represent testing set
# train represent training set
# valid represent validation set
# #### training set is 70%
# #### testing set is 20%
# #### validation set is 10%
#
# #### Adenocarcinoma
# Adenocarcinoma of the lung: Lung adenocarcinoma is the most common form of lung cancer
# accounting for 30 percent of all cases overall and about 40 percent
# of all non-small cell lung cancer occurrences. Adenocarcinomas are
# found in several common cancers, including breast, prostate and colorectal.
# Adenocarcinomas of the lung are found in the outer region of the lung
# in glands that secrete mucus and help us breathe.
# Symptoms include coughing, hoarseness, weight loss and weakness.
#
# #### Large cell carcinoma
# Large-cell undifferentiated carcinoma: Large-cell undifferentiated carcinoma lung cancer grows and spreads quickly and can
# be found anywhere in the lung. This type of lung cancer usually accounts for 10
# to 15 percent of all cases of NSCLC.
# Large-cell undifferentiated carcinoma tends to grow and spread quickly.
#
# #### Squamous cell carcinoma
# Squamous cell: This type of lung cancer is found centrally in the lung,
# where the larger bronchi join the trachea to the lung,
# or in one of the main airway branches.
# Squamous cell lung cancer is responsible for about 30 percent of all non-small
# cell lung cancers, and is generally linked to smoking.
#
# #### And the last folder is the normal CT-Scan images

# %%
from tensorflow.keras.preprocessing.image import load_img
from keras.applications.imagenet_utils import preprocess_input
# First, we'll import pandas and numpy, two data processing libraries
import pandas as pd
import numpy as np
import os,random

# We'll also import seaborn and matplot, twp Python graphing libraries
import seaborn as sns
import matplotlib.pyplot as plt
# Import the needed sklearn libraries
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder

# The Keras library provides support for neural networks and deep learning
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, SpatialDropout2D, Activation, Lambda, Flatten, LSTM
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
#from tensorflow.keras.utils import np_utils
from tensorflow.keras import utils

# %%
# Load on image from folder
train_folder = '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train'
test_folder = '/Users/jenny/MLGroupProjectData/MLGroupProjectData/test'
valid_folder = '/Users/jenny/MLGroupProjectData/MLGroupProjectData/valid'

normal_folder = '/normal'
adenocarcinoma_folder = '/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'
large_cell_carcinoma_folder = '/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa'
squamous_cell_carcinoma_folder = '/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'

# %%
os.listdir(train_folder)
# Out:
# ['.DS_Store',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa',
#  'normal',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa']

# %%
from glob import glob
from PIL import Image

def plot_images(imgs, rows=5):
    # Set figure to 15 inches x 8 inches
    figure = plt.figure(figsize=(25, 12))
    cols = len(imgs) // rows + 1
    for i in range(len(imgs)):
        subplot = figure.add_subplot(rows, cols, i + 1)
        subplot.axis('Off')
        plt.imshow(imgs[i])

def plot_images_for_filenames(filenames, rows=5):
    imgs = [plt.imread(f'{filename}') for filename in filenames]
    return plot_images(imgs, rows)

# %%
sample_adenocarcinoma_images = glob(train_folder + adenocarcinoma_folder + '/*.png')
print (sample_adenocarcinoma_images)
print ("Images of Adenocarcinoma lungs")
plot_images_for_filenames(sample_adenocarcinoma_images)
# Out:
# ['/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000000 (6).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000005 (3).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000005 (9).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000008 (10).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000009 (3).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000009 (7).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000013 (4).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000013 (8).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000014 (7).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000015 (10).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000015 (4).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000015 (9).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000016 (9).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000017 (6).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000017 (8).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000018 (5).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000019 (5).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000020 (10).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000020 (5).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000020 (6).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000021 (3).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000021 (4).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000021 (5).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000021 (6).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000021 (8).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000022 (10).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000022 (2).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000022 (8).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000022 (9).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000022.png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000023 (10).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000023 (5).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000023 (7).png', '/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/adenocarcinom ...
# Images of Adenocarcinoma lungs

# %%
sample17_images = glob(train_folder + normal_folder + '/17.png')
print (sample17_images)
print ("Images of Normal lungs")
plot_images_for_filenames(sample17_images)
# Out:
# ['/Users/jenny/MLGroupProjectData/MLGroupProjectData/train/normal/17.png']
# Images of Normal lungs

# %% [markdown]
# ### Set up callbacks for training
#
# #### learning_rate_reduction: This reduces the Learning Rate during training.
# #### early_stops: EarlyStopping stops the training if the model is not learning is not improving.
# #### checkpointer: ModelCheckpoint saves best weights of the model.

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

learning_rate_reduction = ReduceLROnPlateau(monitor='loss', 
                                            patience=5, 
                                            verbose=2, 
                                            factor=0.5,                                            
                                            min_lr=0.000001)

early_stops = EarlyStopping(monitor='loss', 
                            min_delta=0, 
                            patience=6, 
                            verbose=2, 
                            mode='auto')

checkpointer = ModelCheckpoint(filepath = 'cis3115.{epoch:02d}-{accuracy:.6f}.hdf5',
                               verbose=2,
                               save_best_only=True, 
                               save_weights_only = True)

# %%
# Read data from the folders

IMAGE_SIZE = (224, 224)

print ("Reading training images from: " ,train_folder)
print ("Reading validation images from: " ,validate_folder)

# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
#        rotation_range=10,
#        width_shift_range=0.1,
#        height_shift_range=0.1,
        rescale=1./255,
#        shear_range=0.1,
#        zoom_range=0.1,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

valid_datagen=ImageDataGenerator(rescale=1./255)

batch_size = 8
#batch_size = 32              # This performs better but might take too much memory

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
print ("===== Setting up training image generator")
train_generator = train_datagen.flow_from_directory(
        train_folder,  # this is the target directory
        target_size=IMAGE_SIZE,  # all images will be resized to 150x150
        batch_size=batch_size,
        #color_mode="rgb", 
        class_mode='categorical')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
print ("===== Setting up test image generator")
validation_generator = test_datagen.flow_from_directory(
        test_folder,
        target_size=IMAGE_SIZE,
        batch_size=batch_size,
        #color_mode="rgb", 
        class_mode='categorical')

print ("===== Setting up valid image generator")
valid_generator = valid_datagen.flow_from_directory(
        valid_folder,
        target_size=IMAGE_SIZE,
        batch_size=batch_size,
        #color_mode="rgb", 
        class_mode='categorical')

# We will display the loss and the accuracy of the model for each epoch
# NOTE: this is a little fancier display than is shown in the textbook
def display_training_curves(training, validation, title, subplot):
    if subplot%10==1: # set up the subplots on the first call
        plt.subplots(figsize=(10,10), facecolor='#F0F0F0')
        plt.tight_layout()
    ax = plt.subplot(subplot)
    ax.set_facecolor('#F8F8F8')
    ax.plot(training)
    ax.plot(validation)
    ax.set_title('model '+ title)
    ax.set_ylabel(title)
    #ax.set_ylim(0.28,1.05)
    ax.set_xlabel('epoch')
    ax.legend(['train', 'valid'])
# Out:
# Reading training images from:  /Users/jenny/MLGroupProjectData/MLGroupProjectData/train
# Reading validation images from:  /Users/jenny/MLGroupProjectData/MLGroupProjectData/valid
# ===== Setting up training image generator
# Found 613 images belonging to 4 classes.
# ===== Setting up test image generator
# Found 315 images belonging to 4 classes.
# ===== Setting up valid image generator
# Found 72 images belonging to 4 classes.

# %%
# Set up the Neural Network

# Number of catagories of images
OUTPUT_SIZE = 4
# ==== Select one of the pre-trained models from Keras.  Samples are shown below
#pretrained_model = tf.keras.applications.DenseNet201(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.EfficientNetB4(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.ResNet152V2(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
pretrained_model = tf.keras.applications.Xception(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])

# Set the following to False so that the pre-trained weights are not changed 
pretrained_model.trainable = False 

model = Sequential()
#  Start with the pretrained model defined above
model.add(pretrained_model)

# Flatten 2D images into 1D data for final layers like traditional neural network
model.add(GlobalAveragePooling2D())
model.add(Dense(OUTPUT_SIZE, activation='softmax'))

print ("Pretrained model used:")
pretrained_model.summary()

print ("Final model created:")
model.summary()

# Compile neural network model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Pretrained model used:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 111, 111, 32  864         ['input_4[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 111, 111, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 111, 111, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 109, 109, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 109, 109, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 109, 109, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 109, 109, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 109, 109, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 109, 109, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 109, 109, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_13 (Conv2D)             (None, 55, 55, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 55, 55, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 55, 55, 128)  512        ['conv2d_13[0][0]']
#  rmalization)
#
#  add_24 (Add)                   (None, 55, 55, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 55, 55, 128)  0          ['add_24[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 55, 55, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 55, 55, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 55, 55, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 55, 55, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 256)  32768       ['add_24[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 256)  1024       ['conv2d_14[0][0]']
#  rmalization)
#
#  add_25 (Add)                   (None, 28, 28, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 28, 28, 256)  0          ['add_25[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 28, 28, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 28, 28, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 28, 28, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 28, 28, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 728)  186368      ['add_25[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 14, 14, 728)  2912       ['conv2d_15[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 14, 14, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_26[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_27 (Add)                   (None, 14, 14, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_26[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_27[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_28 (Add)                   (None, 14, 14, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_27[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_28[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_29 (Add)                   (None, 14, 14, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_28[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_29[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_30 (Add)                   (None, 14, 14, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_29[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 14, 14, 728)  0          ['add_30[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 14, 14, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 14, 14, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 14, 14, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_31 (Add)                   (None, 14, 14, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_30[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_31[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_32 (Add)                   (None, 14, 14, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_31[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_32[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_33 (Add)                   (None, 14, 14, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_32[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_33[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 14, 14, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 14, 14, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_34 (Add)                   (None, 14, 14, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_33[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 14, 14, 728)  0          ['add_34[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 14, 14, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 14, 14, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 14, 14, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 14, 14, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 14, 14, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_16 (Conv2D)             (None, 7, 7, 1024)   745472      ['add_34[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 7, 7, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 1024)  4096        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (None, 7, 7, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_11[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 7, 7, 1536)  1582080     ['add_35[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 7, 7, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 7, 7, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 7, 7, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 7, 7, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 7, 7, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
# ==================================================================================================
# Total params: 20,861,480
# Trainable params: 0
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________
# Final model created:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d_3   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 4)                 8196
#
# =================================================================
# Total params: 20,869,676
# Trainable params: 8,196
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
# Train the model with the images in the folders
history = model.fit(
        train_generator,
        steps_per_epoch=25,                     # Number of images to process per epoch 
        epochs=10,                              # Number of epochs
        callbacks=[learning_rate_reduction, early_stops],
        validation_data=validation_generator,
        validation_steps=20                     # Number of images from validation set to test
        )

print ("Final training accuracy = ",history.history['accuracy'][-1])
print ("Final testing accuracy = ",history.history['val_accuracy'][-1])
# Out:
# Epoch 1/10
# 25/25 [==============================] - 49s 2s/step - loss: 1.1872 - accuracy: 0.4518 - val_loss: 1.0923 - val_accuracy: 0.5312 - lr: 0.0010
# Epoch 2/10
# 25/25 [==============================] - 39s 2s/step - loss: 0.9866 - accuracy: 0.5584 - val_loss: 1.0308 - val_accuracy: 0.5188 - lr: 0.0010
# Epoch 3/10
# 25/25 [==============================] - 40s 2s/step - loss: 0.8942 - accuracy: 0.5500 - val_loss: 0.9155 - val_accuracy: 0.5813 - lr: 0.0010
# Epoch 4/10
# 25/25 [==============================] - 39s 2s/step - loss: 0.8044 - accuracy: 0.6400 - val_loss: 0.9184 - val_accuracy: 0.5188 - lr: 0.0010
# Epoch 5/10
# 25/25 [==============================] - 38s 2s/step - loss: 0.7569 - accuracy: 0.6701 - val_loss: 0.8844 - val_accuracy: 0.5875 - lr: 0.0010
# Epoch 6/10
# 25/25 [==============================] - 39s 2s/step - loss: 0.7326 - accuracy: 0.6950 - val_loss: 0.8803 - val_accuracy: 0.5813 - lr: 0.0010
# Epoch 7/10
# 25/25 [==============================] - 40s 2s/step - loss: 0.6965 - accuracy: 0.6950 - val_loss: 0.8604 - val_accuracy: 0.6125 - lr: 0.0010
# Epoch 8/10
# 25/25 [==============================] - 39s 2s/step - loss: 0.6986 - accuracy: 0.7000 - val_loss: 0.8624 - val_accuracy: 0.5562 - lr: 0.0010
# Epoch 9/10
# 25/25 [==============================] - 40s 2s/step - loss: 0.5878 - accuracy: 0.7700 - val_loss: 0.8638 - val_accuracy: 0.5875 - lr: 0.0010
# Epoch 10/10
# 25/25 [==============================] - 39s 2s/step - loss: 0.6011 - accuracy: 0.8020 - val_loss: 0.8170 - val_accuracy: 0.6000 - lr: 0.0010
# Final training accuracy =  0.8020304441452026
# Final testing accuracy =  0.6000000238418579

# %%
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 211)
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 212)

# %%
# Set up the Neural Network

# Number of catagories of images
OUTPUT_SIZE = 4
# ==== Select one of the pre-trained models from Keras.  Samples are shown below
#pretrained_model = tf.keras.applications.DenseNet201(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.EfficientNetB4(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.InceptionV3(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.ResNet152V2(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
pretrained_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])
#pretrained_model = tf.keras.applications.Xception(weights='imagenet', include_top=False ,input_shape=[*IMAGE_SIZE, 3])

# Set the following to False so that the pre-trained weights are not changed 
pretrained_model.trainable = False 

model = Sequential()
#  Start with the pretrained model defined above
model.add(pretrained_model)

# Flatten 2D images into 1D data for final layers like traditional neural network
model.add(GlobalAveragePooling2D())
model.add(Dense(OUTPUT_SIZE, activation='softmax'))

print ("Pretrained model used:")
pretrained_model.summary()

print ("Final model created:")
model.summary()

# Compile neural network model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Pretrained model used:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Final model created:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_4   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 14,716,740
# Trainable params: 2,052
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Train the model with the images in the folders
history = model.fit(
        train_generator,
        steps_per_epoch=25,                     # Number of images to process per epoch 
        epochs=10,                              # Number of epochs
        callbacks=[learning_rate_reduction, early_stops],
        validation_data=validation_generator,
        validation_steps=20                     # Number of images from validation set to test
        )

print ("Final training accuracy = ",history.history['accuracy'][-1])
print ("Final testing accuracy = ",history.history['val_accuracy'][-1])
# Out:
# Epoch 1/10
# 25/25 [==============================] - 81s 3s/step - loss: 1.3890 - accuracy: 0.2741 - val_loss: 1.2795 - val_accuracy: 0.4500 - lr: 0.0010
# Epoch 2/10
# 25/25 [==============================] - 78s 3s/step - loss: 1.2999 - accuracy: 0.4150 - val_loss: 1.2539 - val_accuracy: 0.4125 - lr: 0.0010
# Epoch 3/10
# 25/25 [==============================] - 80s 3s/step - loss: 1.2126 - accuracy: 0.4600 - val_loss: 1.2218 - val_accuracy: 0.5188 - lr: 0.0010
# Epoch 4/10
# 25/25 [==============================] - 79s 3s/step - loss: 1.2207 - accuracy: 0.4975 - val_loss: 1.2321 - val_accuracy: 0.4625 - lr: 0.0010
# Epoch 5/10
# 25/25 [==============================] - 79s 3s/step - loss: 1.1581 - accuracy: 0.5584 - val_loss: 1.1490 - val_accuracy: 0.5688 - lr: 0.0010
# Epoch 6/10
# 25/25 [==============================] - 79s 3s/step - loss: 1.0976 - accuracy: 0.5650 - val_loss: 1.1885 - val_accuracy: 0.5250 - lr: 0.0010
# Epoch 7/10
# 25/25 [==============================] - 79s 3s/step - loss: 1.1153 - accuracy: 0.5431 - val_loss: 1.1826 - val_accuracy: 0.5125 - lr: 0.0010
# Epoch 8/10
# 25/25 [==============================] - 79s 3s/step - loss: 1.0796 - accuracy: 0.5279 - val_loss: 1.1508 - val_accuracy: 0.4750 - lr: 0.0010
# Epoch 9/10
# 25/25 [==============================] - 79s 3s/step - loss: 1.1032 - accuracy: 0.5200 - val_loss: 1.1037 - val_accuracy: 0.5500 - lr: 0.0010
# Epoch 10/10
# 25/25 [==============================] - 78s 3s/step - loss: 1.0394 - accuracy: 0.5550 - val_loss: 1.1098 - val_accuracy: 0.5063 - lr: 0.0010
# Final training accuracy =  0.5550000071525574
# Final testing accuracy =  0.5062500238418579

# %%
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 211)
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 212)

# %%
# Set up the Neural Network

# Number of catagories of images
OUTPUT_SIZE = 4

#  ========================== Define your own CNN =================================
model = Sequential()
#  Apply convolution filters and then reduce image size using MaxPooling
model.add(Conv2D(8, kernel_size=(3, 3), activation='relu', input_shape=[*IMAGE_SIZE, 3]))
model.add(Conv2D(8, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#  Apply convolution filters and then reduce image size using MaxPooling
model.add(Conv2D(16, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#  Apply convolution filters and then reduce image size using MaxPooling
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#  Apply convolution filters and then reduce image size using MaxPooling
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# Flatten 2D images into 1D data for final layers like traditional neural network
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(OUTPUT_SIZE, activation='softmax'))

print ("Final model created:")
model.summary()

# Compile neural network model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Final model created:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 222, 222, 8)       224
#
#  conv2d_18 (Conv2D)          (None, 220, 220, 8)       584
#
#  max_pooling2d_4 (MaxPooling  (None, 110, 110, 8)      0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 108, 108, 16)      1168
#
#  max_pooling2d_5 (MaxPooling  (None, 54, 54, 16)       0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 52, 52, 32)        4640
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 32)       0
#  2D)
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_7 (Dense)             (None, 256)               2359552
#
#  dense_8 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 2,385,692
# Trainable params: 2,385,692
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model with the images in the folders
history = model.fit(
        train_generator,
        steps_per_epoch=25,                     # Number of images to process per epoch 
        epochs=10,                              # Number of epochs
        callbacks=[learning_rate_reduction, early_stops],
        validation_data=validation_generator,
        validation_steps=20                     # Number of images from validation set to test
        )

print ("Final training accuracy = ",history.history['accuracy'][-1])
print ("Final testing accuracy = ",history.history['val_accuracy'][-1])
# Out:
# Epoch 1/10
# 25/25 [==============================] - 13s 429ms/step - loss: 1.2920 - accuracy: 0.3350 - val_loss: 1.1891 - val_accuracy: 0.3625 - lr: 0.0010
# Epoch 2/10
# 25/25 [==============================] - 10s 407ms/step - loss: 1.0909 - accuracy: 0.5500 - val_loss: 1.0142 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 3/10
# 25/25 [==============================] - 10s 414ms/step - loss: 0.9024 - accuracy: 0.6500 - val_loss: 1.1060 - val_accuracy: 0.4625 - lr: 0.0010
# Epoch 4/10
# 25/25 [==============================] - 10s 406ms/step - loss: 0.9098 - accuracy: 0.5850 - val_loss: 1.6589 - val_accuracy: 0.3875 - lr: 0.0010
# Epoch 5/10
# 25/25 [==============================] - 10s 408ms/step - loss: 0.7735 - accuracy: 0.6954 - val_loss: 1.9824 - val_accuracy: 0.4313 - lr: 0.0010
# Epoch 6/10
# 25/25 [==============================] - 10s 411ms/step - loss: 0.5633 - accuracy: 0.7400 - val_loss: 2.6428 - val_accuracy: 0.4563 - lr: 0.0010
# Epoch 7/10
# 25/25 [==============================] - 10s 400ms/step - loss: 0.7653 - accuracy: 0.6853 - val_loss: 1.6979 - val_accuracy: 0.3500 - lr: 0.0010
# Epoch 8/10
# 25/25 [==============================] - 10s 408ms/step - loss: 0.6927 - accuracy: 0.7157 - val_loss: 2.9213 - val_accuracy: 0.3438 - lr: 0.0010
# Epoch 9/10
# 25/25 [==============================] - 10s 403ms/step - loss: 0.5719 - accuracy: 0.7550 - val_loss: 2.5702 - val_accuracy: 0.3938 - lr: 0.0010
# Epoch 10/10
# 25/25 [==============================] - 10s 400ms/step - loss: 0.5432 - accuracy: 0.8223 - val_loss: 2.5099 - val_accuracy: 0.4000 - lr: 0.0010
# Final training accuracy =  0.8223350048065186
# Final testing accuracy =  0.4000000059604645

# %%
display_training_curves(history.history['loss'], history.history['val_loss'], 'loss', 211)
display_training_curves(history.history['accuracy'], history.history['val_accuracy'], 'accuracy', 212)

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames=os.listdir("/Users/jenny/MLGroupProjectData/MLGroupProjectData/valid")
test_filenames
# Out:
# ['adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa',
#  'normal',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa']

# %%
test_adenocarcinoma_filenames=os.listdir("/Users/jenny/MLGroupProjectData/MLGroupProjectData/valid/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib")
test_adenocarcinoma_filenames
# Out:
# ['000108 (7).png',
#  '000108 (8).png',
#  '000109 (3).png',
#  '000109 (4).png',
#  '000109 (8).png',
#  '000110 (7).png',
#  '000111 (2).png',
#  '000112 (2).png',
#  '000112 (9).png',
#  '000113 (3).png',
#  '000113.png',
#  '000114 (10).png',
#  '000114.png',
#  '000115 (2).png',
#  '000115 (5).png',
#  '000115 (9).png',
#  '000115.png',
#  '000116 (3).png',
#  '000116 (5).png',
#  '000116 (8).png',
#  '000116 (9).png',
#  '000117 (6).png',
#  '000117.png']

# %%
len(test_adenocarcinoma_filenames)
# Out:
# 23

# %%
test_large_filenames=os.listdir("/Users/jenny/MLGroupProjectData/MLGroupProjectData/valid/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa")
len(test_large_filenames)
# Out:
# 21

# %%
normal=os.listdir("/Users/jenny/MLGroupProjectData/MLGroupProjectData/valid/normal")
len(normal)
# Out:
# 13

# %%
test_squamous_filenames=os.listdir("/Users/jenny/MLGroupProjectData/MLGroupProjectData/valid/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa")
len(test_squamous_filenames)
# Out:
# 15

# %%
filenames=valid_generator.filenames
filenames
# Out:
# ['adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000108 (7).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000108 (8).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000109 (3).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000109 (4).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000109 (8).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000110 (7).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000111 (2).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000112 (2).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000112 (9).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000113 (3).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000113.png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000114 (10).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000114.png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000115 (2).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000115 (5).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000115 (9).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000115.png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000116 (3).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000116 (5).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000116 (8).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000116 (9).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000117 (6).png',
#  'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\\000117.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000108 (2).png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000108.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000109.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000110 (2).png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000110.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000111 (2).png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000111.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000112.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000113 (2).png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000113.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000114.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000115 (3).png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000115.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000116.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000118 (2).png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000120.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000122.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000126.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000128.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000130.png',
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\\000131.png',
#  'normal\\003828_02_01_174.png',
#  'normal\\004007_01_01_519.png',
#  'normal\\004162_01_01_150.png',
#  'normal\\4 (2).png',
#  'normal\\4 - Copy (2).png',
#  'normal\\5.png',
#  'normal\\6 - Copy (2) - Copy.png',
#  'normal\\6 - Copy (3).png',
#  'normal\\6 - Copy.png',
#  'normal\\7 - Copy (2).png',
#  'normal\\7 - Copy (3).png',
#  'normal\\7.png',
#  'normal\\8 - Copy (3).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000108 (3).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000110 (6).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000111.png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000112.png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000114 (4).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000114 (6).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000115 (2).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000115 (5).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000116 (2).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000117 (4).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000117 (6).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000118 (4).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000118 (5).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000119 (5).png',
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\\000119.png']

# %%
pd.set_option('display.max_rows', None)

# %%
categories=[]

for filename in filenames:
    category=filename.split('.')[0]  #my_str.__contains__(target)
    if category.__contains__('normal'):
        categories.append(2)
    elif category.__contains__('squamous'):
        categories.append(3)
    elif category.__contains__('large'):
        categories.append(1)  
    else:
        categories.append(0)
        
df=pd.DataFrame({'filename':filenames,'category':categories})
df
# Out:
#                                              filename  category
# 0   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 1   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 2   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 3   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 4   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 5   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 6   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 7   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 8   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 9   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 10  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 11  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 12  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 13  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 14  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 15  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 16  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 17  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 18  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 19  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 20  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 21  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 22  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0
# 23  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 24  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 25  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 26  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 27  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 28  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 29  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 30  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 31  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 32  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 33  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 34  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 35  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 36  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 37  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 38  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 39  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 40  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 41  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 42  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 43  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1
# 44                        normal\003828_02_01_174.png         2
# 45                        normal\004007_01_01_519.png         2
# 46                        normal\004162_01_01_150.png         2
# 47                                   normal\4 (2).png         2
# 48                            normal\4 - Copy (2).png         2
# 49                                       normal\5.png         2
# 50                     normal\6 - Copy (2) - Copy.png         2
# 51                            normal\6 - Copy (3).png         2
# 52                                normal\6 - Copy.png         2
# 53                            normal\7 - Copy (2).png         2
# 54                            normal\7 - Copy (3).png         2
# 55                                       normal\7.png         2
# 56                            normal\8 - Copy (3).png         2
# 57  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 58  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 59  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 60  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 61  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 62  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 63  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 64  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 65  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 66  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 67  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 68  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 69  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 70  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3
# 71  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3

# %%
df['category'].value_counts()
# Out:
# 3    23
# 2    21
# 1    15
# 0    13
# Name: category, dtype: int64

# %%
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
nb_samples=len(filenames)
nb_samples
# Out:
# 72

# %% [markdown]
# # Classification

# %%
y_predict=model.predict(valid_generator)
# Out:
# 9/9 [==============================] - 0s 36ms/step

# %%
Y_val=df['category']

# %%
y_predict.shape
# Out:
# (72, 4)

# %%
y_predict
# Out:
# array([[7.6291239e-01, 8.2386799e-02, 1.7390875e-02, 1.3730997e-01],
#        [3.0848572e-01, 7.5940602e-03, 2.8734906e-03, 6.8104666e-01],
#        [5.9817505e-01, 5.5514552e-02, 6.4952336e-03, 3.3981520e-01],
#        [7.8104472e-01, 6.0048733e-02, 2.2019392e-03, 1.5670462e-01],
#        [2.7183114e-05, 4.0443861e-03, 6.9959879e-01, 2.9632965e-01],
#        [7.1105057e-01, 1.7188501e-02, 2.8713632e-03, 2.6888955e-01],
#        [3.6290747e-01, 8.9284569e-02, 3.6480736e-03, 5.4415995e-01],
#        [6.7913777e-01, 1.1657306e-02, 2.2699980e-03, 3.0693483e-01],
#        [6.5509719e-01, 1.4793466e-01, 5.9560873e-03, 1.9101210e-01],
#        [2.5329573e-02, 5.5683321e-01, 7.6101013e-02, 3.4173620e-01],
#        [5.0474828e-01, 3.4296311e-02, 2.8200141e-01, 1.7895392e-01],
#        [7.6436293e-01, 4.4846814e-02, 6.8167504e-04, 1.9010861e-01],
#        [1.7407063e-01, 5.7641122e-02, 5.1195477e-03, 7.6316875e-01],
#        [6.5923530e-01, 1.8310711e-01, 9.3439678e-03, 1.4831358e-01],
#        [7.9091191e-01, 4.9368322e-02, 1.6151620e-03, 1.5810461e-01],
#        [2.0762777e-01, 7.1305478e-01, 5.8889452e-02, 2.0427996e-02],
#        [3.3031425e-01, 7.6710889e-03, 1.3784802e-03, 6.6063619e-01],
#        [7.7071899e-01, 6.2657520e-02, 1.4153301e-03, 1.6520812e-01],
#        [7.2239470e-01, 4.2494193e-02, 1.7690200e-03, 2.3334202e-01],
#        [2.6494154e-01, 7.0408010e-01, 2.3922820e-02, 7.0555280e-03],
#        [6.8819666e-01, 2.6431444e-01, 2.7813015e-03, 4.4707637e-02],
#        [3.7075315e-10, 2.4130223e-12, 1.0000000e+00, 3.4648169e-09],
#        [4.8469216e-01, 8.2850628e-02, 2.4557808e-02, 4.0789938e-01],
#        [8.2553023e-01, 4.1071650e-02, 1.8595761e-03, 1.3153854e-01],
#        [6.3558900e-01, 7.8757741e-02, 7.2749085e-03, 2.7837837e-01],
#        [6.4229250e-01, 4.5526225e-02, 2.8390898e-03, 3.0934212e-01],
#        [1.3875112e-01, 1.0566461e-02, 1.9001137e-03, 8.4878236e-01],
#        [2.9746059e-01, 3.0903358e-02, 1.1540042e-03, 6.7048198e-01],
#        [7.0711750e-01, 1.3389392e-02, 5.1399728e-04, 2.7897903e-01],
#        [6.3891163e-09, 3.6705423e-13, 9.9999964e-01, 4.0983105e-07],
#        [7.1105453e-05, 1.9937659e-06, 9.9981612e-01, 1.1073690e-04],
#        [2.3434679e-03, 7.0437184e-04, 9.9668223e-01, 2.6989655e-04],
#        [4.4340670e-01, 2.2062628e-02, 2.6017362e-02, 5.0851327e-01],
#        [3.7963107e-01, 8.8306107e-03, 1.2747672e-03, 6.1026353e-01],
#        [1.5706952e-01, 8.9993007e-02, 1.2231393e-02, 7.4070615e-01],
#        [5.4430795e-01, 6.0324453e-02, 2.9682883e-03, 3.9239928e-01],
#        [1.5057331e-01, 6.5933365e-01, 1.6054967e-03, 1.8848759e-01],
#        [5.9592012e-02, 9.3118078e-01, 3.3553608e-04, 8.8916188e-03],
#        [7.1514450e-02, 8.0834085e-01, 1.5337865e-02, 1.0480683e-01],
#        [6.2878054e-01, 2.3441750e-01, 1.9956008e-03, 1.3480635e-01],
#        [4.9449813e-01, 3.1314799e-01, 2.3896797e-02, 1.6845712e-01],
#        [4.4012356e-01, 2.7811430e-02, 1.3131117e-03, 5.3075188e-01],
#        [3.8390002e-07, 5.1736920e-10, 9.9998736e-01, 1.2316410e-05],
#        [3.2543534e-01, 5.9081174e-02, 1.1396235e-03, 6.1434382e-01],
#        [1.4007090e-12, 1.2823855e-15, 1.0000000e+00, 5.2583733e-09],
#        [3.8614830e-01, 7.1894534e-02, 1.0163319e-02, 5.3179389e-01],
#        [1.1252408e-01, 6.6657174e-01, 9.5972046e-03, 2.1130703e-01],
#        [3.8390002e-07, 5.1736920e-10, 9.9998736e-01, 1.2316410e-05],
#        [7.6909411e-01, 3.7437961e-02, 2.1423933e-03, 1.9132558e-01],
#        [4.3526277e-01, 2.1852948e-01, 8.2627274e-03, 3.3794495e-01],
#        [1.7860072e-04, 5.5341428e-07, 9.9975568e-01, 6.5137530e-05],
#        [8.4749663e-01, 4.6173330e-02, 1.5805107e-02, 9.0524942e-02],
#        [1.4786799e-01, 6.1867702e-01, 1.3545114e-01, 9.8003931e-02],
#        [3.9185985e-15, 1.2606595e-17, 1.0000000e+00, 2.6198282e-10],
#        [1.8645328e-01, 3.0964036e-03, 1.4358748e-03, 8.0901450e-01],
#        [6.5213633e-01, 1.4964646e-01, 8.5897483e-03, 1.8962748e-01],
#        [1.0782945e-01, 8.5529590e-01, 1.8581945e-02, 1.8292718e-02],
#        [2.5559431e-01, 3.8433343e-02, 3.8686269e-03, 7.0210367e-01],
#        [4.4690862e-02, 9.4493109e-01, 2.4213532e-03, 7.9566995e-03],
#        [1.9328575e-01, 1.2629928e-01, 1.5842499e-03, 6.7883074e-01],
#        [3.8775492e-02, 1.1697825e-02, 9.3158394e-01, 1.7942734e-02],
#        [3.7116134e-01, 3.6100108e-02, 1.3701041e-03, 5.9136850e-01],
#        [3.6290058e-01, 3.1287760e-02, 4.5882431e-03, 6.0122329e-01],
#        [3.4217298e-01, 2.7000157e-02, 6.7799550e-04, 6.3014895e-01],
#        [3.0377479e-02, 5.8575876e-02, 7.2694737e-01, 1.8409921e-01],
#        [4.5342541e-01, 1.7407607e-02, 4.7514742e-04, 5.2869183e-01],
#        [7.1105453e-05, 1.9937659e-06, 9.9981612e-01, 1.1073690e-04],
#        [3.8442573e-01, 1.0024963e-01, 1.5355790e-03, 5.1378906e-01],
#        [7.0148271e-01, 4.2662650e-02, 2.7910746e-03, 2.5306356e-01],
#        [4.1617641e-01, 1.7086421e-01, 4.5286375e-03, 4.0843081e-01],
#        [6.9470483e-01, 1.8432651e-02, 1.5161749e-03, 2.8534636e-01],
#        [6.1212927e-01, 7.9010181e-02, 1.7412422e-02, 2.9144809e-01]],
#       dtype=float32)

# %%
predict=[]

for i in range(72):
    predict.append(np.argmax(y_predict[i]))

# %%
dff=pd.DataFrame({'filename':filenames,'category':categories,'Predict':predict})
dff
# Out:
#                                              filename  category  Predict
# 0   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 1   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        3
# 2   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 3   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 4   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        2
# 5   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 6   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        3
# 7   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 8   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 9   adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        1
# 10  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 11  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 12  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        3
# 13  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 14  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 15  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        1
# 16  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        3
# 17  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 18  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 19  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        1
# 20  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 21  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        2
# 22  adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\000...         0        0
# 23  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 24  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 25  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 26  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 27  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 28  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 29  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        2
# 30  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        2
# 31  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        2
# 32  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 33  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 34  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 35  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 36  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        1
# 37  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        1
# 38  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        1
# 39  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 40  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        0
# 41  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 42  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        2
# 43  large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa\...         1        3
# 44                        normal\003828_02_01_174.png         2        2
# 45                        normal\004007_01_01_519.png         2        3
# 46                        normal\004162_01_01_150.png         2        1
# 47                                   normal\4 (2).png         2        2
# 48                            normal\4 - Copy (2).png         2        0
# 49                                       normal\5.png         2        0
# 50                     normal\6 - Copy (2) - Copy.png         2        2
# 51                            normal\6 - Copy (3).png         2        0
# 52                                normal\6 - Copy.png         2        1
# 53                            normal\7 - Copy (2).png         2        2
# 54                            normal\7 - Copy (3).png         2        3
# 55                                       normal\7.png         2        0
# 56                            normal\8 - Copy (3).png         2        1
# 57  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 58  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        1
# 59  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 60  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        2
# 61  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 62  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 63  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 64  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        2
# 65  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 66  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        2
# 67  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        3
# 68  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        0
# 69  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        0
# 70  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        0
# 71  squamous.cell.carcinoma_left.hilum_T1_N2_M0_II...         3        0

# %%
dff.where(dff['category']!=dff['Predict']).count()
# Out:
# filename    44
# category    44
# Predict     44
# dtype: int64
